# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'} 
webpage = requests.get('https://www.ambitionbox.com/list-of-companies?page=1',headers = headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
#print(soup.prettify())

# %%
soup.find_all('h1')[0].text.strip
# Out:
# <function str.strip(chars=None, /)>

# %%
type(soup.find_all('h1')[0])
# Out:
# bs4.element.Tag

# %% [markdown]
# <h2 style = "color:blue">Finding out the name of the Company</h2>

# %%
company_name = soup.find_all('h2')
for i in company_name:
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# Wipro
# Capgemini
# HDFC Bank
# ICICI Bank
# Infosys
# HCLTech
# Tech Mahindra
# Genpact
# Axis Bank
# Teleperformance
# Concentrix Corporation
# Jio
# Amazon
# IBM
# Reliance Retail
# HDB Financial Services
# Larsen & Toubro Limited
# Companies by  Industry
# Companies by  Locations
# Companies by  Type
# Companies by  Badges

# %%
company_ratings = soup.find_all('span',class_= 'companyCardWrapper__companyRatingValue')
company_ratings
# Out:
# [<span class="companyCardWrapper__companyRatingValue">3.8</span>,
#  <span class="companyCardWrapper__companyRatingValue">4.0</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.9</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.8</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.9</span>,
#  <span class="companyCardWrapper__companyRatingValue">4.0</span>,
#  <span class="companyCardWrapper__companyRatingValue">4.0</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.8</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.7</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.7</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.9</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.9</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.6</span>,
#  <span class="companyCardWrapper__companyRatingValue">3.9</span>,
# ...

# %%
for i in company_ratings:
    print(i.text)
# Out:
# 3.8
# 4.0
# 3.9
# 3.8
# 3.9
# 4.0
# 4.0
# 3.8
# 3.7
# 3.7
# 3.9
# 3.9
# 3.6
# 3.9
# 4.0
# 4.1
# 4.1
# 4.0
# 4.0
# 4.1

# %%
company_reviews = soup.find_all('span',class_= 'companyCardWrapper__ActionCount')[::6]
company_reviews
# Out:
# [<span class="companyCardWrapper__ActionCount">74k</span>,
#  <span class="companyCardWrapper__ActionCount">46.9k</span>,
#  <span class="companyCardWrapper__ActionCount">42.3k</span>,
#  <span class="companyCardWrapper__ActionCount">39.8k</span>,
#  <span class="companyCardWrapper__ActionCount">34.4k</span>,
#  <span class="companyCardWrapper__ActionCount">34.3k</span>,
#  <span class="companyCardWrapper__ActionCount">33.9k</span>,
#  <span class="companyCardWrapper__ActionCount">32.2k</span>,
#  <span class="companyCardWrapper__ActionCount">29k</span>,
#  <span class="companyCardWrapper__ActionCount">28k</span>,
#  <span class="companyCardWrapper__ActionCount">26.5k</span>,
#  <span class="companyCardWrapper__ActionCount">22.2k</span>,
#  <span class="companyCardWrapper__ActionCount">22.2k</span>,
#  <span class="companyCardWrapper__ActionCount">22.1k</span>,
#  <span class="companyCardWrapper__ActionCount">20.8k</span>,
# ...

# %%
len(company_reviews)

# %%
for i in company_reviews:
    print(i.text)
# Out:
# 74k
# 46.9k
# 42.3k
# 39.8k
# 34.4k
# 34.3k
# 33.9k
# 32.2k
# 29k
# 28k
# 26.5k
# 22.2k
# 22.2k
# 22.1k
# 20.8k
# 20.8k
# 19.9k
# 19k
# 18.3k
# 16.8k

# %%
company_type = soup.find_all('span',class_= 'companyCardWrapper__interLinking')
company_type
# Out:
# [<span class="companyCardWrapper__interLinking">
#  									IT Services &amp; Consulting | 1 Lakh+ Employees | Public | 56 years old | Mumbai +344 more
#  								</span>,
#  <span class="companyCardWrapper__interLinking">
#  									IT Services &amp; Consulting | 1 Lakh+ Employees | Public | 35 years old | Dublin +175 more
#  								</span>,
#  <span class="companyCardWrapper__interLinking">
#  									IT Services &amp; Consulting | 1 Lakh+ Employees | Forbes Global 2000 | 30 years old | Teaneck. New Jersey. +163 more
#  								</span>,
#  <span class="companyCardWrapper__interLinking">
#  									IT Services &amp; Consulting | 1 Lakh+ Employees | Public | 79 years old | Bangalore/Bengaluru +276 more
#  								</span>,
#  <span class="companyCardWrapper__interLinking">
#  									IT Services &amp; Consulting | 1 Lakh+ Employees | Public | 57 years old | Paris +140 more
#  								</span>,
#  <span class="companyCardWrapper__interLinking">
# ...

# %%
len(company_type)
# Out:
# 20

# %%
for i in company_type:
    temp = i.text.strip().split('|')
    print(temp[4])
# Out:
#  Mumbai +344 more
#  Dublin +175 more
#  Teaneck. New Jersey. +163 more
#  Bangalore/Bengaluru +276 more
#  Paris +140 more
#  Mumbai +1544 more
#  Mumbai +1286 more
#  Bengaluru/Bangalore +181 more
#  Noida +183 more
#  Pune +267 more
#  New York +111 more
#  Mumbai +1301 more
#  Paris +183 more
#  Fremont +115 more
#  Navi Mumbai +1172 more
#  Seattle +446 more
#  Armonk +146 more
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[81], line 3
#       1 for i in company_type:
#       2     temp = i.text.strip().split('|')
# ----> 3     print(temp[4])
#
# IndexError: list index out of range

# %% [markdown]
# <h2 style="color:blue">Now, let do them as a whole</h2>

# %%
company = soup.find_all('div',class_= 'companyCardWrapper')
len(company)
# Out:
# 20

# %%
names = []
reviews = []
ratings = []
no_of_employee=[]
c_type = []
how_old=[]
hq=[]

for i in company:
    
    no_of_employee.append(i.find('span',class_= 'companyCardWrapper__interLinking').text.strip().split('|')[1])
    c_type.append(i.find('span',class_= 'companyCardWrapper__interLinking').text.strip().split('|')[2])
    how_old.append(i.find('span',class_= 'companyCardWrapper__interLinking').text.strip().split('|')[3])
    #hq.append(i.find('span',class_= 'companyCardWrapper__interLinking').text.strip().split('|')[4])
    ratings.append(i.find('span',class_= 'companyCardWrapper__companyRatingValue').text.strip())
    reviews.append(i.find('span',class_= 'companyCardWrapper__ActionCount').text.strip())
    names.append(i.find('h2').text.strip())
    
df=pd.DataFrame({'names':names,
   'reviews':reviews,
   'ratings':ratings,
   'no_of_employee':no_of_employee,
   'c_type':c_type,
   'how_old':how_old,
   })

# %%
df
# Out:
#                       names reviews ratings          no_of_employee  \
# 0                       TCS     74k     3.8      1 Lakh+ Employees
# 1                 Accenture   46.9k     4.0      1 Lakh+ Employees
# 2                 Cognizant   42.3k     3.9      1 Lakh+ Employees
# 3                     Wipro   39.8k     3.8      1 Lakh+ Employees
# 4                 Capgemini   34.4k     3.9      1 Lakh+ Employees
# 5                 HDFC Bank   34.3k     4.0      1 Lakh+ Employees
# 6                ICICI Bank   33.9k     4.0      1 Lakh+ Employees
# 7                   Infosys   32.2k     3.8      1 Lakh+ Employees
# 8                   HCLTech     29k     3.7      1 Lakh+ Employees
# 9             Tech Mahindra     28k     3.7      1 Lakh+ Employees
# 10                  Genpact   26.5k     3.9      1 Lakh+ Employees
# 11                Axis Bank   22.2k     3.9   50k-1 Lakh Employees
# 12          Teleperformance   22.2k     3.6   50k-1 Lakh Employees
# ...

# %%
len(no_of_employee)
# Out:
# 20

# %%
len(c_type)
# Out:
# 20

# %%
len(how_old)
# Out:
# 20

# %%
len(c_type)
# Out:
# 20

# %%
len(ratings)
# Out:
# 20

# %%
len(reviews)
# Out:
# 20

# %%
len(names)
# Out:
# 0

# %%
df.shape
# Out:
# (20, 6)

# %% [markdown]
# <h2 style = "color:blue">Now,creating dataframe for all the pages</h2>

# %%
final=pd.DataFrame()
for j in range(1,4):
    
    url = 'https://www.ambitionbox.com/list-of-companies?page={}'.format(j) 
    webpage = requests.get(url,headers = headers).text
    soup=BeautifulSoup(webpage,'lxml')
    company = soup.find_all('div',class_= 'companyCardWrapper')
    
    names = []
    reviews = []
    ratings = []
    no_of_employee=[]
    c_type = []
    how_old=[]
    hq=[]

    for i in company:

        no_of_employee.append(i.find('span',class_= 'companyCardWrapper__interLinking').text.strip().split('|')[1])
        c_type.append(i.find('span',class_= 'companyCardWrapper__interLinking').text.strip().split('|')[2])
        how_old.append(i.find('span',class_= 'companyCardWrapper__interLinking').text.strip().split('|')[3])
        #hq.append(i.find('span',class_= 'companyCardWrapper__interLinking').text.strip().split('|')[4])
        ratings.append(i.find('span',class_= 'companyCardWrapper__companyRatingValue').text.strip())
        reviews.append(i.find('span',class_= 'companyCardWrapper__ActionCount').text.strip())
        names.append(i.find('h2').text.strip())

    df=pd.DataFrame({'names':names,
       'reviews':reviews,
       'ratings':ratings,
       'no_of_employee':no_of_employee,
       'c_type':c_type,
       'how_old':how_old,
       })
    
    final = final.append(df,ignore_index=True)
    
    
final
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6720\3273538616.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df,ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6720\3273538616.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df,ignore_index=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6720\3273538616.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df,ignore_index=True)
#                          names reviews ratings          no_of_employee  \
# 0                          TCS     74k     3.8      1 Lakh+ Employees
# 1                    Accenture   46.9k     4.0      1 Lakh+ Employees
# ...
